# %%
# Install folium for map visualization
# !pip install folium

# Import libraries
import pandas as pd
import folium
from folium.plugins import HeatMap, MarkerCluster
import unicodedata
# Out:
# Requirement already satisfied: folium in /Users/zactseng/anaconda3/lib/python3.11/site-packages (0.18.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from folium) (1.26.3)
# Requirement already satisfied: requests in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zactseng/anaconda3/lib/python3.11/site-packages (from requests->folium) (2024.6.2)

# %%
# Part 1: Load and Clean Data for EV Charging Stations
# ========================================================
# This section handles the loading and cleaning of the EV charging station data.

# Step 1.1: Load the EV charging station dataset
# Load the EV charging station data from a specified path
df = pd.read_csv('/Users/zactseng/Documents/ECE 1724 Bio/Project/EV_Charging_Stations_Placement_Optimization/Quebec_EV_charging_station.csv')

# Step 1.2: Normalize 'City' column by removing accents and converting to lowercase
# This ensures that cities with accents are properly filtered (e.g., "Montréal" becomes "montreal")
df['City'] = df['City'].apply(lambda x: unicodedata.normalize('NFKD', x).encode('ASCII', 'ignore').decode('utf-8').lower())

# Step 1.3: Filter for rows where 'City' is 'montreal' and select specific columns
# Only include Montreal EV charging stations with relevant columns
montreal_df = df[df['City'] == 'montreal']
montreal_df = montreal_df[['City', 'Latitude', 'Longitude', 'Price', 'Pricing']]

# Check if there is any data for Montreal before saving
if not montreal_df.empty:
    # Save the filtered dataset for later use
    output_path = 'Montreal_EV_charging_stations.csv'
    montreal_df.to_csv(output_path, index=False)
else:
    print("No data found for 'Montreal' in the dataset after cleaning.")

# %%
# Part 2: Visualize EV Charging Stations with Price-Based Markers
# ========================================================
# This section adds markers for each EV charging station in Montreal,
# with different colors to represent different pricing levels.

# Initialize a map centered on Montreal
montreal_map = folium.Map(location=[45.5017, -73.5673], zoom_start=12)

# Step 2.1: Add markers for each charging station with color coding based on price
# Orange for Price > 1, Blue for Price <= 1
for index, row in montreal_df.iterrows():
    marker_color = "orange" if row['Price'] > 1 else "blue"

    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"Price: {row['Price']}, Pricing: {row['Pricing']}",
        icon=folium.Icon(color=marker_color, icon="bolt", prefix="fa")
    ).add_to(montreal_map)

montreal_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ac34a980465f28307fb968e276d0749 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ac34a980465f28307fb968e276d0749&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ac34a980465f28307fb968e276d0749 = L.map(
#                 &quot;map_2ac34a980465f28307fb968e276d0749&quot;,
#                 {
#                     center: [45.5017, -73.5673],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b41d6b50e99035fa4bb48cbb91420a2a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b41d6b50e99035fa4bb48cbb91420a2a.addTo(map_2ac34a980465f28307fb968e276d0749);
#
#
#             var marker_0ebdf0ef3ee58921380f002dec6931fe = L.marker(
#                 [45.597136, -73.56931],
#                 {}
#             ).addTo(map_2ac34a980465f28307fb968e276d0749);
#
#
#             var icon_78de1ebd4643b8589318cb957f1d2ca1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0ebdf0ef3ee58921380f002dec6931fe.setIcon(icon_78de1ebd4643b8589318cb957f1d2ca1);
#
#
#         var popup_7f66229e9d92e23d1eef133c11095283 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a99677f8052812e983ad034160e4a32 = $(`&lt;div id=&quot;html_3a99677f8052812e983ad034160e4a32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Price: 1.0, Pricing: per hour&lt;/div&gt;`)[0];
#                 popup_7f66229e9d92e23d1eef133c11095283.setContent(html_3a99677f8052812e983ad034160e4a32);
#
#
#
#         marker_0ebdf0ef3ee58921380f002dec6931fe.bindPopup(popup_7f66229e9d92e23d1eef133c11095283)
#         ;
#
#
#
#
#             var marker_6c228aaa05e731a8fde690ff0b792beb = L.marker(
#                 [45.597136, -73.56931],
#                 {}
#             ).addTo(map_2ac34a980465f28307fb968e276d0749);
#
#
#             var icon_1a6abc8900051785e4a5e99fdfefc5bb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6c228aaa05e731a8fde690ff0b792beb.setIcon(icon_1a6abc8900051785e4a5e99fdfefc5bb);
#
#
#         var popup_b190caef1c5530fff6d8b82fd2800db6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58779b77ada40bdd7f8bfa37e0a1d8d5 = $(`&lt;div id=&quot;html_58779b77ada40bdd7f8bfa37e0a1d8d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Price: 1.0, Pricing: per hour&lt;/div&gt;`)[0];
#                 popup_b190caef1c5530fff6d8b82fd2800db6.setContent(html_58779b77ada40bdd7f8bfa37e0a1d8d5);
#
#
#
#         marker_6c228aaa05e731a8fde690ff0b792beb.bindPopup(popup_b190caef1c5530fff6d8b82fd2800db6)
#         ;
#
#
#
#
#             var marker_cdf0fc859a9c799b1e1c123d4e0d5aa4 = L.marker(
#                 [45.605348, -73.585155],
#                 {}
#             ).addTo(map_2ac34a980465f28307fb968e276d0749);
#
#
#             var icon_100a13a0aaef17ffe92a0e7437d6d1e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cdf0fc859a9c799b1e1c123d4e0d5aa4.setIcon(icon_100a13a0aaef17ffe92a0e7437d6d1e2);
#
#
#         var popup_4162490347eb7ad24214ad026da0bb60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3b9062a1ac8817885434cd9bd3f0f44 = $(`&lt;div id=&quot;html_c3b9062a1ac8817885434cd9bd3f0f44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Price: 1.0, Pricing: per hour&lt;/div&gt;`)[0];
#                 popup_4162490347eb7ad24214ad026da0bb60.setContent(html_c3b9062a1ac8817885434cd9bd3f0f44);
#
#
#
#         marker_cdf0fc859a9c799b1e1c123d4e0d5aa4.bindPopup(popup_4162490347eb7ad24214ad026da0bb60)
#         ;
#
#
#
#
#             var marker_eab7bfcc680c6c93cccf39379401aca4 = L.marker(
#                 [45.605348, -73.585155],
#                 {}
#             ).addTo(map_2ac34a980465f28307fb968e276d0749);
#
#
#             var icon_b559ce18c54299912c21785fcaa65cdc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;

# %%
# Part 3: Separate Heat Map for Traffic Flow Density
# ========================================================
# This section creates a separate heat map to represent the density of traffic flows
# across different locations in Montreal, so it does not overlap with the EV charging map.

# Step 3.1: Load the traffic flow dataset and clean it
# Load traffic flow data from a specified path
traffic_df = pd.read_csv('/Users/zactseng/Documents/ECE 1724 Bio/Project/EV_Charging_Stations_Placement_Optimization/Montreal_traffic_flow.csv')

# Drop rows with missing values in latitude, longitude, or traffic count
traffic_df = traffic_df.dropna(subset=['latitude', 'longitude', 'average_vehicle_count'])

# Step 3.2: Prepare data for the heat map (latitude, longitude, intensity)
# This data format is required for HeatMap to visualize traffic flow intensity
heat_data = traffic_df[['latitude', 'longitude', 'average_vehicle_count']].values.tolist()

# Initialize a new map for the heat map to avoid overlap
montreal_heat_map = folium.Map(location=[45.5017, -73.5673], zoom_start=12)

# Step 3.3: Add HeatMap to visualize traffic density with a color gradient for intensity
HeatMap(
    heat_data,
    radius=15,                   # Larger radius for denser coverage
    blur=10,                     # Set blur for smoother transitions
    min_opacity=0.2,             # Minimum opacity for less dense areas
    max_opacity=0.8,             # Maximum opacity for denser areas
    max_val=traffic_df['average_vehicle_count'].max(), # Normalize colors by max traffic count
    gradient={0.2: 'blue', 0.4: 'cyan', 0.6: 'lime', 0.8: 'orange', 1: 'red'} # Custom gradient
).add_to(montreal_heat_map)

montreal_heat_map
# Out:
# /var/folders/sq/ksk005sx1k1b1v7q1kfnjlhc0000gn/T/ipykernel_6142/2431988086.py:21: UserWarning: The `max_val` parameter is no longer necessary. The largest intensity is calculated automatically.
#   HeatMap(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c86e75028f90b69f1b1c895697f9bdb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c86e75028f90b69f1b1c895697f9bdb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c86e75028f90b69f1b1c895697f9bdb = L.map(
#                 &quot;map_6c86e75028f90b69f1b1c895697f9bdb&quot;,
#                 {
#                     center: [45.5017, -73.5673],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca90b369221c8952e074b2d7e5c8fcda = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ca90b369221c8952e074b2d7e5c8fcda.addTo(map_6c86e75028f90b69f1b1c895697f9bdb);
#
#
#             var heat_map_f1d9dda82548d6f425985aec32a0a9c1 = L.heatLayer(
#                 [[45.54115543, -73.57370733, 250.0], [45.53397851, -73.60500716, 596.0], [45.52345, -73.62317, 673.0], [45.46293, -73.59767, 333.0], [45.52373, -73.60553, 596.0], [45.55545, -73.6373, 337.0], [45.54786, -73.60702, 1218.0], [45.53499, -73.59494, 485.0], [45.6363, -73.56511, 454.0], [45.58451, -73.50855, 315.0], [45.53259, -73.59017, 213.0], [45.53714224, -73.6119394, 875.0], [45.65287, -73.51073, 589.0], [45.58368, -73.59186, 981.0], [45.5533, -73.5805, 1031.0], [45.61365, -73.59911, 543.0], [45.44193, -73.69248, 470.0], [45.6435, -73.55385, 176.0], [45.531499, -73.650035, 104.0], [45.48718, -73.54546, 92.0], [45.53936362, -73.60501425, 564.0], [45.47922, -73.55887, 794.0], [45.48945, -73.58447, 513.0], [45.55524, -73.66841, 781.0], [45.52127, -73.54975, 591.0], [45.53754, -73.57747, 826.0], [45.58849, -73.50887, 313.0], [45.59093, -73.53853, 657.0], [45.5864, -73.55459, 330.0], [45.54255, -73.61191, 426.0], [45.50836, -73.57132, 887.0], [45.5051, -73.5574, 438.0], [45.50478, -73.55765, 712.0], [45.48687, -73.55227, 383.0], [45.52043, -73.59761, 912.0], [45.58918, -73.52047, 103.0], [45.52815, -73.55737, 693.0], [45.52947, -73.546, 1117.0], [45.53279, -73.56739, 284.0], [45.53519, -73.57244, 1062.0], [45.53903, -73.56882, 253.0], [45.48502839, -73.86490461, 633.0], [45.55182, -73.60835, 1010.0], [45.54067, -73.59143, 874.0], [45.64946, -73.5791, 457.0], [45.65078, -73.56146, 314.0], [45.52911, -73.61805, 498.0], [45.57405, -73.6329, 1021.0], [45.52737, -73.60209, 505.0], [45.55464, -73.55472, 512.0], [45.46438, -73.61579, 655.0], [45.57733, -73.51509, 265.0], [45.51899335, -73.59438775, 941.0], [45.46639, -73.60015, 105.0], [45.50499, -73.5734, 902.0], [45.53051, -73.56959, 509.0], [45.55259, -73.5484, 281.0], [45.54717, -73.598, 1021.0], [45.53185, -73.61226, 479.0], [45.54626, -73.63757, 265.0], [45.52224, -73.70748, 646.0], [45.53951243, -73.58174897, 868.0], [45.51743, -73.69983, 605.0], [45.54577, -73.61964, 268.0], [45.47528, -73.59406, 261.0], [45.49323, -73.55744, 1267.0], [45.57158, -73.60255, 578.0], [45.51015, -73.68815, 660.0], [45.51307, -73.69284, 637.0], [45.49428, -73.63764, 336.0], [45.55837, -73.66733, 1028.0], [45.47046, -73.60736, 665.0], [45.48862608, -73.62478819, 813.0], [45.56824, -73.65344, 871.0], [45.59023, -73.61811, 547.0], [45.51886, -73.58744, 1257.0], [45.53596, -73.56131, 704.0], [45.55154, -73.65551, 641.0], [45.54074212, -73.69573446, 493.0], [45.54811968, -73.62469205, 785.0], [45.46148933, -73.62421067, 944.0], [45.47840199, -73.62025154, 439.0], [45.527655, -73.63788667, 1255.0], [45.43058325, -73.63479718, 763.0], [45.53442848, -73.6606884, 835.0], [45.48223218, -73.58512494, 240.0], [45.5588335, -73.59834765, 973.0], [45.49574435, -73.57943465, 566.0], [45.49805364, -73.57748071, 658.0], [45.53043051, -73.64745864, 476.0], [45.55033585, -73.67091158, 735.0], [45.5492206, -73.63535825, 450.0], [45.55024435, -73.62936576, 342.0], [45.56148488, -73.5424326, 567.0], [45.57367271, -73.65674275, 375.0], [45.52587687, -73.55943462, 683.0], [45.50137206, -73.56191174, 486.0], [45.5038264, -73.56175854, 825.0], [45.48752379, -73.55956745, 222.0], [45.50629646, -73.5669461, 324.0], [45.52037611, -73.61498913, 470.0], [45.53978194, -73.57508214, 419.0], [45.44095377, -73.65133534, 283.0], [45.50085649, -73.63218594, 983.0], [45.52575287, -73.61021024, 409.0], [45.47964005, -73.57784835, 255.0], [45.53781204, -73.60153864, 1347.0], [45.52970482, -73.7232502, 723.0], [45.5088303, -73.56158154, 867.0], [45.51058725, -73.56532962, 603.0], [45.59648834, -73.53502758, 478.0], [45.49877993, -73.55285951, 559.0], [45.54897334, -73.59156746, 978.0], [45.49464575, -73.65283135, 714.0], [45.48123057, -73.57798003, 741.0], [45.51801638, -73.58170323, 1115.0], [45.52418402, -73.62589099, 731.0], [45.48058951, -73.62287295, 906.0], [45.50537008, -73.71127718, 266.0], [45.50089123, -73.57468652, 998.0], [45.56089467, -73.63643

# %%
# Part 4: Cluster Map for Traffic Flow Density
# ========================================================
# This section visualizes traffic flow density using a MarkerCluster.
# Clusters group nearby traffic points, showing dense regions with marker counts.

# Initialize a new map centered on Montreal for the cluster map
montreal_cluster_map = folium.Map(location=[45.5017, -73.5673], zoom_start=12)

# Step 4.1: Initialize a MarkerCluster to group traffic flow markers
marker_cluster = MarkerCluster().add_to(montreal_cluster_map)

# Step 4.2: Add traffic data points to the cluster, showing average vehicle count on popup
for index, row in traffic_df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"Average Vehicle Count: {row['average_vehicle_count']}"
    ).add_to(marker_cluster)

montreal_cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e069862a0f1ea05bd58df51d668c13ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e069862a0f1ea05bd58df51d668c13ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e069862a0f1ea05bd58df51d668c13ec = L.map(
#                 &quot;map_e069862a0f1ea05bd58df51d668c13ec&quot;,
#                 {
#                     center: [45.5017, -73.5673],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bce289c0196bbdf8b14d0c7ab1340806 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bce289c0196bbdf8b14d0c7ab1340806.addTo(map_e069862a0f1ea05bd58df51d668c13ec);
#
#
#             var marker_cluster_2abd9cba785dbadc0897091e59238eee = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_29e2a5d65b7d7ee759aca302fb7b2a00 = L.marker(
#                 [45.54115543, -73.57370733],
#                 {}
#             ).addTo(marker_cluster_2abd9cba785dbadc0897091e59238eee);
#
#
#         var popup_be357b4d59989e37d28acce97f792ca9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cf5411ba558d10ba4f8b53c286caa59 = $(`&lt;div id=&quot;html_1cf5411ba558d10ba4f8b53c286caa59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Average Vehicle Count: 250.0&lt;/div&gt;`)[0];
#                 popup_be357b4d59989e37d28acce97f792ca9.setContent(html_1cf5411ba558d10ba4f8b53c286caa59);
#
#
#
#         marker_29e2a5d65b7d7ee759aca302fb7b2a00.bindPopup(popup_be357b4d59989e37d28acce97f792ca9)
#         ;
#
#
#
#
#             var marker_953b49bbd5c88d8e842338edfefa3147 = L.marker(
#                 [45.53397851, -73.60500716],
#                 {}
#             ).addTo(marker_cluster_2abd9cba785dbadc0897091e59238eee);
#
#
#         var popup_c7a514dcc7f779b9c1d84c5175364186 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f268d8e6405c3ba9b7a58a534580c29 = $(`&lt;div id=&quot;html_9f268d8e6405c3ba9b7a58a534580c29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Average Vehicle Count: 596.0&lt;/div&gt;`)[0];
#                 popup_c7a514dcc7f779b9c1d84c5175364186.setContent(html_9f268d8e6405c3ba9b7a58a534580c29);
#
#
#
#         marker_953b49bbd5c88d8e842338edfefa3147.bindPopup(popup_c7a514dcc7f779b9c1d84c5175364186)
#         ;
#
#
#
#
#             var marker_a74f3dbb151d0834e84f7fc64843c842 = L.marker(
#                 [45.52345, -73.62317],
#                 {}
#             ).addTo(marker_cluster_2abd9cba785dbadc0897091e59238eee);
#
#
#         var popup_654cc46927d323b3e906165c31813876 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84a0c00d455a9d1fbbbf66b531eb804c = $(`&lt;div id=&quot;html_84a0c00d455a9d1fbbbf66b531eb804c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Average Vehicle Count: 673.0&lt;/div&gt;`)[0];
#                 popup_654cc46927d323b3e906165c31813876.setContent(html_84a0c00d455a9d1fbbbf66b531eb804c);
#
#
#
#         marker_a74f3dbb151d0834e84f7fc64843c842.bindPopup(popup_654cc46927d323b3e906165c31813876)
#         ;
#
#
#
#
#             var marker_54965542e491472123fac0e310cef21f = L.marker(
#                 [45.46293, -73.59767],
#                 {}
#             ).addTo(marker_cluster_2abd9cba785dbadc0897091e59238eee);
#
#
#         var popup_8bc02b200eea7b1fd713194f75ddbd5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa828d81f43752a903cc611f74814bb1 = $(`&lt;div id=&quot;html_fa828d81f43752a903cc611f74814bb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Average Vehicle Count: 333.0&lt;/div&gt;`)[0];
#                 popup_8bc02b200eea7b1fd713194f75ddbd5a.setContent(html_fa828d81f43752a903cc611f74814bb1);
#
#
#
#         marker_54965542e491472123fac0e310cef21f.bindPopup(popup_8bc02b200eea7b1fd713194f75ddbd5a)
#         ;
#
#
#
#
#             var marker_930ebe7ec33b60f0ae8920df7ba6c4df = L.marker(
#                 [45.52373, -73.60553],
#                 {}
#             ).addTo(marker_cluster_2abd9cba785dbadc0897091e59238eee);
#
#
#         var popup_9f6fb035733aed0c8136cbabbd59704e = L.popup({&quot;maxWidth&q
